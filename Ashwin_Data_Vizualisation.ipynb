# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashwinks1995/hello/blob/master/Ashwin_Data_Vizualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports

# pandas
import pandas as pd
from pandas import Series,DataFrame

import datetime

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ```
# For Stock market data
#
# ```

# %%
! pip install yahoo-finance
import pandas as pd
# Out:
# ...
#     100% |████████████████████████████████| 81kB 3.0MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/58/77/5b/66026e0fa7af2ee5926a516a70d3df95e17f952c570bc5aee6
# done
#   Stored in directory: /root/.cache/pip/wheels/5d/1a/1e/0350bb3df3e74215cd91325344cc86c2c691f5306eb4d22c77
# Successfully built yahoo-finance simplejson
# ...

# %%
import pandas_datareader as web   # Package and modules for importing data; this code may change depending on pandas version
start = datetime.datetime(2008,1,1)
end = datetime.date.today()
apple = web.DataReader("AAPL", "yahoo", start, end)
microsoft = web.DataReader("MSFT", "yahoo", start, end)
google = web.DataReader("GOOG", "yahoo", start, end)

import matplotlib.pyplot as plt   # Import matplotlib
 
  
stocks = pd.DataFrame({"AAPL": apple["Adj Close"],
                      "MSFT": microsoft["Adj Close"],
                      "GOOG": google["Adj Close"]})
 
stocks.head()

stocks.plot(grid = True)
